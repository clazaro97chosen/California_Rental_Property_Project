# %% [markdown]
# # Lets get started

# %%
import numpy as np
import pandas as pd
import re

# %%
 s = pd.Series(np.random.randn(5), index=['a', 'b', 'c', 'd', 'e'])
s
# Out:
# a    2.084986
# b    0.014501
# c    1.446014
# d    1.211824
# e   -0.432419
# dtype: float64

# %%
Freshman = pd.read_csv('FreshmanRetention.csv',delimiter = ',')

# %%
Freshman.head()
# Out:
#    UNIQUE_ID    COHORT NATIVE_COLLEGE GENDER ETHNICITY RESIDENCY AOA_RSNCODE  \
# 0    1689903  FTF_2108        40-OCOB      F     WHITE  Resident    Mand MCA
# 1    2010608  FTF_2108         48-CLA      M     WHITE  Resident    Acad MCA
# 2    2776325  FTF_2108         48-CLA      F     WHITE  Resident    Acad MCA
# 3    4063890  FTF_2108         48-CLA      F     WHITE  Resident    Acad MCA
# 4    5685393  FTF_2108        40-OCOB      M     HISPA  Resident    Mand MCA
#
#    MothersEd  FathersEd  HS_GPA PARTNER_SCHOOL  SATRead  SATMath  \
# 0        6.0        6.0   3.750             No    490.0    450.0
# 1        7.0        5.0   4.075             No    680.0    710.0
# 2        6.0        6.0   3.890             No    520.0    570.0
# 3        7.0        7.0   4.190             No    670.0    600.0
# 4        6.0        6.0   3.588             No    720.0    600.0
#
#    FreshmanRetained
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# ...

# %%
Freshman.head()
# Out:
#    UNIQUE_ID    COHORT NATIVE_COLLEGE GENDER ETHNICITY RESIDENCY AOA_RSNCODE  \
# 0    1689903  FTF_2108        40-OCOB      F     WHITE  Resident    Mand MCA
# 1    2010608  FTF_2108         48-CLA      M     WHITE  Resident    Acad MCA
# 2    2776325  FTF_2108         48-CLA      F     WHITE  Resident    Acad MCA
# 3    4063890  FTF_2108         48-CLA      F     WHITE  Resident    Acad MCA
# 4    5685393  FTF_2108        40-OCOB      M     HISPA  Resident    Mand MCA
#
#    MothersEd  FathersEd  HS_GPA PARTNER_SCHOOL  SATRead  SATMath  \
# 0        6.0        6.0   3.750             No    490.0    450.0
# 1        7.0        5.0   4.075             No    680.0    710.0
# 2        6.0        6.0   3.890             No    520.0    570.0
# 3        7.0        7.0   4.190             No    670.0    600.0
# 4        6.0        6.0   3.588             No    720.0    600.0
#
#    FreshmanRetained
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# ...

# %%
Freshman.tail()
# Out:
#         UNIQUE_ID    COHORT NATIVE_COLLEGE GENDER ETHNICITY RESIDENCY  \
# 21021  3274899137  FTF_2148        10-CAGR      M     WHITE  Resident
# 21022  1022467736  FTF_2148        10-CAGR      M     WHITE  Resident
# 21023  1713187049  FTF_2148        10-CAGR      F     WHITE  Resident
# 21024  1759375618  FTF_2148        10-CAGR      F     WHITE   Non Res
# 21025  1011414683  FTF_2148        10-CAGR      M     HISPA  Resident
#
#       AOA_RSNCODE  MothersEd  FathersEd  HS_GPA PARTNER_SCHOOL  SATRead  \
# 21021    Mand MCA        5.0        7.0    3.01             No    620.0
# 21022       Early        6.0        7.0    2.93             No    520.0
# 21023       Early        6.0        6.0     NaN             No    570.0
# 21024    Acad MCA        6.0        5.0     NaN             No    530.0
# 21025       Early        3.0        4.0     NaN             No    600.0
#
#        SATMath  FreshmanRetained
# 21021    550.0                 0
# 21022    620.0                 1
# ...

# %%
Freshman.index
# Out:
# RangeIndex(start=0, stop=21026, step=1)

# %%
Freshman.columns
# Out:
# Index(['UNIQUE_ID', 'COHORT', 'NATIVE_COLLEGE', 'GENDER', 'ETHNICITY',
#        'RESIDENCY', 'AOA_RSNCODE', 'MothersEd', 'FathersEd', 'HS_GPA',
#        'PARTNER_SCHOOL', 'SATRead', 'SATMath', 'FreshmanRetained'],
#       dtype='object')

# %%
Freshman.describe()
# Out:
#           UNIQUE_ID     MothersEd     FathersEd        HS_GPA       SATRead  \
# count  2.102600e+04  20285.000000  20103.000000  20601.000000  20931.000000
# mean   2.137564e+09      5.380084      5.421280      3.841494    600.528881
# std    1.243646e+09      1.550306      1.631192      0.447736     77.961929
# min    5.979000e+04      1.000000      1.000000      0.000000    300.000000
# 25%    1.054471e+09      4.000000      4.000000      3.636000    550.000000
# 50%    2.152420e+09      6.000000      6.000000      3.880000    600.000000
# 75%    3.213045e+09      6.000000      7.000000      4.102000    650.000000
# max    4.294965e+09      7.000000      7.000000      4.985000    800.000000
#
#             SATMath  FreshmanRetained
# count  20928.000000      21026.000000
# mean     635.979071          0.943166
# std       75.535564          0.231531
# min      340.000000          0.000000
# 25%      580.000000          1.000000
# 50%      640.000000          1.000000
# ...
